# %%
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
import scipy as scipy
from scipy import special, optimize
import seaborn as sns
# %matplotlib inline

# %%
resp = pd.read_csv('../project/data/ehresp_2014/ehresp_2014.csv')
resp.head()
#resp.shape
# Out:
#          tucaseid  tulineno  eeincome1      erbmi  erhhch  erincome  erspemch  \
# 0  20140101140007         1         -2  33.200001       1        -1        -1
# 1  20140101140011         1          1  22.700001       3         1        -1
# 2  20140101140028         1          2  49.400002       3         5        -1
# 3  20140101140063         1         -2  -1.000000       3        -1        -1
# 4  20140101140168         1          2  31.000000       3         5        -1
#
#    ertpreat  ertseat  ethgt    ...      eumeat  eumilk  euprpmel  eusoda  \
# 0        30        2      0    ...           1       2         1      -1
# 1        45       14      0    ...           1       2         1      -1
# 2        60        0      0    ...          -1      -1         2       2
# 3         0        0      0    ...           2       2         1       1
# 4        65        0      0    ...           1       2         1       2
#
#    eustores  eustreason  eutherm  euwgt  euwic  exincome1
# 0         2           1        2    170      1          2
# 1         1           2        2    128      2          0
# 2        -1          -1       -1    270      2         12
# 3         2           6       -1     -2      2          2
# 4         1           1        2    210      1          0
#
# [5 rows x 37 columns]

# %%
resp.columns
# Out:
# Index([u'tucaseid', u'tulineno', u'eeincome1', u'erbmi', u'erhhch',
#        u'erincome', u'erspemch', u'ertpreat', u'ertseat', u'ethgt', u'etwgt',
#        u'eudietsoda', u'eudrink', u'eueat', u'euexercise', u'euexfreq',
#        u'eufastfd', u'eufastfdfrq', u'euffyday', u'eufdsit', u'eufinlwgt',
#        u'eusnap', u'eugenhth', u'eugroshp', u'euhgt', u'euinclvl',
#        u'euincome2', u'eumeat', u'eumilk', u'euprpmel', u'eusoda', u'eustores',
#        u'eustreason', u'eutherm', u'euwgt', u'euwic', u'exincome1'],
#       dtype='object')

# %%
resp_bmi_seat = resp[['erbmi', 'ertseat']]
resp_bmi_seat = resp_bmi_seat[resp_bmi_seat.erbmi != -1]
# resp_bmi_seat.erbmi.value_counts()

# %%
x = resp_bmi_seat.erbmi
y = resp_bmi_seat.ertseat
plt_hist = resp_bmi_seat.erbmi.hist(bins=40)
print plt_hist
# Out:
# Axes(0.125,0.125;0.775x0.775)

# %%
resp_bmi = resp[['erbmi', 'ertpreat', 'ertseat']]
resp_bmi = resp_bmi[resp_bmi.erbmi != -1]

sns.pairplot(resp_bmi, x_vars=['ertpreat','ertseat'], y_vars='erbmi', size=6, aspect=0.7)

# %%
resp_bmi.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1189deed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118f635d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x118fcbcd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11905fe10>]], dtype=object)

# %%
#resp_bmi.groupby('erbmi').hist()

# %%
scipy.stats.normaltest(resp_bmi.erbmi)
# Out:
# NormaltestResult(statistic=2510.4505648790855, pvalue=0.0)

# %%
resp_bmi_reat = resp[['erbmi', 'ertpreat']]
resp_bmi_reat = resp_bmi_reat[resp_bmi_reat.erbmi != -1]
# resp_bmi_seat.erbmi.value_counts()

# %%
x = resp_bmi_reat.erbmi
y = resp_bmi_reat.ertpreat
plt_hist = resp_bmi_reat.erbmi.hist(bins=40)
print plt_hist
# Out:
# Axes(0.125,0.125;0.775x0.775)

# %%
resp_bmi_stores = resp[['erbmi', 'eustores']]
resp_bmi_stores = resp_bmi_stores[resp_bmi_stores.erbmi != -1]
# resp_bmi_seat.erbmi.value_counts()

x = resp_bmi_stores.erbmi
y = resp_bmi_stores.eustores
plt_hist = resp_bmi_stores.erbmi.hist(bins=40)
print plt_hist
# Out:
# Axes(0.125,0.125;0.775x0.775)

# %%
act = pd.read_csv('../project/data/ehact_2014/ehact_2014.csv')
act.head()
#act.shape
# Out:
#          tucaseid  tuactivity_n  eueatsum  euedur  euedur24
# 0  20140101140007             1        -1      -1        -1
# 1  20140101140007             2        -1      -1        -1
# 2  20140101140007             3        -1      -1        -1
# 3  20140101140007             4        -1      -1        -1
# 4  20140101140007             5        -1      -1        -1

# %%
wgts = pd.read_csv('../project/data/ehwgts_2014/ehwgts_2014.csv')
wgts.head()
#wgts.shape
# Out:
#          tucaseid  eufinlwgt001  eufinlwgt002  eufinlwgt003  eufinlwgt004  \
# 0  20140101140007     5372384.0     4547057.0     9104005.0     4748467.0
# 1  20140101140011    27100000.0    35400000.0    49800000.0    56200000.0
# 2  20140101140028    24400000.0    26800000.0    14200000.0    42400000.0
# 3  20140101140063     3268345.0     1379962.0     3984481.0     2504467.0
# 4  20140101140168    34100000.0    25300000.0     5319927.0     6540043.0
#
#    eufinlwgt005  eufinlwgt006  eufinlwgt007  eufinlwgt008  eufinlwgt009  \
# 0     5733486.0     4146183.0     1664931.0     1384541.0     9620782.0
# 1    50000000.0    12600000.0    24300000.0    27600000.0    43000000.0
# 2    36300000.0    34100000.0    32800000.0     6966086.0    29500000.0
# 3     3428945.0     4488051.0      746629.9     5587482.0      806942.9
# 4     4303210.0    18400000.0    23600000.0    14800000.0    25400000.0
#
#        ...       eufinlwgt151  eufinlwgt152  eufinlwgt153  eufinlwgt154  \
# 0      ...          6036034.0     8784856.0     1912823.0     5271794.0
# 1      ...         26500000.0    23000000.0     9509532.0    23400000.0
# 2      ...         33600000.0    36000000.0    25100000.0    35500000.0
# 3      ...          2883778.0     1950272.0     2303951.0     3409027.0
# 4      ...         21400000.0    30500000.0    32800000.0    19400000.0
#
#    eufinlwgt155  eufinlwgt156  eufinlwgt157  eufinlwgt158  eufinlwgt159  \
# 0     1529660.0     5017687.0     4975427.0     4972301.0     1481319.0
# 1    42800000.0     8893482.0    37200000.0    31600000.0    29500000.0
# 2    37700000.0    27300000.0    26100000.0    46100000.0    11100000.0
# 3     2453709.0      629713.2     4809095.0     2103491.0      935877.2
# 4     6974526.0     9683304.0    27300000.0     4822558.0    11600000.0
#
#    eufinlwgt160
# 0     4729550.0
# 1     9530296.0
# 2    23800000.0
# 3     3043285.0
# 4    24400000.0
#
# [5 rows x 161 columns]

# %%
wgts.columns
# Out:
# Index([u'tucaseid', u'eufinlwgt001', u'eufinlwgt002', u'eufinlwgt003',
#        u'eufinlwgt004', u'eufinlwgt005', u'eufinlwgt006', u'eufinlwgt007',
#        u'eufinlwgt008', u'eufinlwgt009',
#        ...
#        u'eufinlwgt151', u'eufinlwgt152', u'eufinlwgt153', u'eufinlwgt154',
#        u'eufinlwgt155', u'eufinlwgt156', u'eufinlwgt157', u'eufinlwgt158',
#        u'eufinlwgt159', u'eufinlwgt160'],
#       dtype='object', length=161)

# %%
merge_act_wgts = pd.merge(act, wgts, on=['tucaseid'], how='left')
df = pd.merge(resp, merge_act_wgts, on=['tucaseid'], how='left')
df.head()
df.shape
# Out:
# (125819, 201)

# %%
resp.columns
# Out:
# Index([u'tucaseid', u'tulineno', u'eeincome1', u'erbmi', u'erhhch',
#        u'erincome', u'erspemch', u'ertpreat', u'ertseat', u'ethgt', u'etwgt',
#        u'eudietsoda', u'eudrink', u'eueat', u'euexercise', u'euexfreq',
#        u'eufastfd', u'eufastfdfrq', u'euffyday', u'eufdsit', u'eufinlwgt',
#        u'eusnap', u'eugenhth', u'eugroshp', u'euhgt', u'euinclvl',
#        u'euincome2', u'eumeat', u'eumilk', u'euprpmel', u'eusoda', u'eustores',
#        u'eustreason', u'eutherm', u'euwgt', u'euwic', u'exincome1'],
#       dtype='object')

# %%
df.erbmi.describe()
# Out:
# count    125819.000000
# mean         26.154665
# std           8.519968
# min          -1.000000
# 25%          22.700001
# 50%          25.799999
# 75%          30.200001
# max          73.599998
# Name: erbmi, dtype: float64

# %%
df.erbmi.hist(bins=40)

# %%
df.ertpreat.hist(bins=40)

# %%
df.ertseat.hist(bins=40)

# %%
resp_1 = resp[['erbmi', 'ertpreat', 'ertseat', 'eudrink', 'eusoda', 'euexercise', 'euexfreq']]
resp_1.head()
# Out:
#        erbmi  ertpreat  ertseat  eudrink  eusoda  euexercise  euexfreq
# 0  33.200001        30        2        2      -1           2        -1
# 1  22.700001        45       14        2      -1           2        -1
# 2  49.400002        60        0        1       2           2        -1
# 3  -1.000000         0        0        1       1           2        -1
# 4  31.000000        65        0        1       2           1         5

# %%
resp_1 = resp_1[resp_1.eudrink != -2]

resp_1.eudrink.value_counts()
# Out:
#  1    7517
#  2    3685
# -3       1
# Name: eudrink, dtype: int64

# %%
resp_1 = resp_1[resp_1.eudrink !=-3]

resp_1.eudrink.value_counts()
# Out:
# 1    7517
# 2    3685
# Name: eudrink, dtype: int64

# %%
print resp_1.eusoda.value_counts()
print resp_1.euexercise.value_counts()
print resp_1.euexfreq.value_counts()
# Out:
#  2    4470
# -1    3685
#  1    3043
# -2       4
# Name: eusoda, dtype: int64
#  1    7008
#  2    4137
# -3      30
# -1      19
# -2       8
# Name: euexercise, dtype: int64
# -1     4194
#  3     1623
#  2     1145
#  7     1117
#  4     1058
#  5      911
#  1      574
#  6      353
#  14      59
#  10      40
#  9       21
#  8       19
# -2       18
#  21      16
#  12      11
#  11       7
#  28       6
#  15       5
#  20       4
#  17       4
# -3        3
#  35       2
#  18       2
#  13       2
#  25       2
#  30       2
#  16       2
#  38       1
#  24       1
# Name: euexfreq, dtype: int64

# %%
resp_1 = resp_1[resp_1.eusoda !=-1]
resp_1 = resp_1[resp_1.eusoda !=-2]
resp_1 = resp_1[resp_1.euexercise !=-1]
resp_1 = resp_1[resp_1.euexercise !=-2]
resp_1 = resp_1[resp_1.euexercise !=-3]

print resp_1.eusoda.value_counts()
print resp_1.euexercise.value_counts()
# Out:
# 2    4452
# 1    3027
# Name: eusoda, dtype: int64
# 1    4678
# 2    2801
# Name: euexercise, dtype: int64

# %%
print resp_1.ertpreat.value_counts(resp_1.ertpreat == 0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-66-3c343056c678> in <module>()
# ----> 1 print resp_1.ertpreat.value_counts(resp_1.ertpreat == 0)
#
# /Users/FrancescaSchott/anaconda/envs/testenv/lib/python2.7/site-packages/pandas/core/base.pyc in value_counts(self, normalize, sort, ascending, bins, dropna)
#     945         from pandas.core.algorithms import value_counts
#     946         result = value_counts(self, sort=sort, ascending=ascending,
# --> 947                               normalize=normalize, bins=bins, dropna=dropna)
#     948         return result
#     949
#
# /Users/FrancescaSchott/anaconda/envs/testenv/lib/python2.7/site-packages/pandas/core/algorithms.pyc in value_counts(values, sort, ascending, normalize, bins, dropna)
#     292         result = result.sort_values(ascending=ascending)
#     293
# --> 294     if normalize:
#     295         result = result / float(counts.sum())
#     296
#
# /Users/FrancescaSchott/anaconda/envs/testenv/lib/python2.7/site-packages/pandas/core/generic.pyc in __nonzero__(self)
#     890         raise ValueError("The truth value of a {0} is ambiguous. "
#     891                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# --> 892                          .format(self.__class__.__name__))
#     893
#     894     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
# resp_2 = resp_1[['erbmi', 'eusoda', 'euexercise']]
# X, y = resp_2.drop('erbmi', axis = 1), resp_2['erbmi']
# knn = KNeighborsClassifier(n_neighbors=3)
# knn.fit(X, y)
# knn.score(X, y)

# %%
sns.pairplot(resp_1, x_vars=['ertpreat','ertseat'], y_vars='erbmi', size=6, aspect=0.7)
