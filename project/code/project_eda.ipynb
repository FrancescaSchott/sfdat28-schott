# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

resp = pd.read_csv('/Users/FrancescaSchott/sfdat/sfdat28-schott/project/data/resp.csv', index_col=0)

# %%
resp.head()
# Out:
#           bmi  primary_eating  secondary_eating  exercise  fast_food  \
# 7   27.500000            30.0               5.0       2.0        1.0
# 34  30.600000            85.0               0.0       2.0        1.0
# 36  18.299999           145.0               0.0       2.0        1.0
# 37  26.500000            60.0               5.0       2.0        2.0
# 38  24.200001            15.0               0.0       1.0        1.0
#
#     food_amount  stores  maj_ind  cat_occ  income_lvl  income_weekly
# 7           3.0     1.0        5        3           1         144.90
# 34          3.0     2.0       13        1           1        1038.46
# 36          3.0     1.0       10        1           1         884.61
# 37          3.0     1.0       12        2           0         415.00
# 38          3.0     1.0        8        1           0         576.92

# %%
resp.stores.value_counts()
# Out:
# 1.0    826
# 2.0    250
# 5.0     50
# 3.0     19
# 4.0      5
# Name: stores, dtype: int64

# %% [markdown]
# ## VISUALIZATION/GRAPHS

# %%
sns.heatmap(resp.corr())
plt.savefig("heatmap.png", transparent=True, bbox_inches='tight')

# %%
plt.hist(resp.income_weekly, bins=20)
plt.savefig('hist_week.png', transparent=True)

# %%
resp.plot(kind='scatter', x='bmi', y='income_weekly')
plt.savefig('bmi_scatter.png', transparent=True)

# %%
resp.plot(kind='scatter', x='primary_eating', y='income_weekly')
plt.savefig('prim_scatter.png', transparent=True)

# %%
resp.plot(kind='scatter', x='secondary_eating', y='income_weekly')
plt.savefig('sec_scatter.png', transparent=True)

# %%
resp[['income_lvl', 'food_amount']].corr()
# Out:
#              income_lvl  food_amount
# income_lvl      1.00000      0.17335
# food_amount     0.17335      1.00000

# %%
resp[['income_lvl', 'exercise']].corr()
# Out:
#             income_lvl  exercise
# income_lvl    1.000000  0.187295
# exercise      0.187295  1.000000

# %%
resp.groupby('cat_occ').income_weekly.mean().plot(kind='bar')
plt.savefig('bar_occ.png', transparent=True)

# %%
resp.groupby('maj_ind').income_weekly.mean().plot(kind='bar')

# %%
resp.groupby('stores').income_weekly.mean().plot(kind='bar')
plt.savefig('bar_stores.png', transparent=True)

# %%
resp.groupby('stores').income_lvl.value_counts()
# Out:
# stores  income_lvl
# 1.0     1             633
#         0             193
# 2.0     1             174
#         0              76
# 3.0     1              18
#         0               1
# 4.0     1               4
#         0               1
# 5.0     1              40
#         0              10
# Name: income_lvl, dtype: int64

# %%
resp.groupby('food_amount').income_weekly.mean().plot(kind='bar')
plt.savefig('bar_food_amt.png', transparent=True)

# %%
resp.groupby('fast_food').income_weekly.mean().plot(kind='bar')

# %%
resp.groupby('exercise').income_weekly.mean().plot(kind='bar')
plt.savefig('bar_exercise.png', transparent=True)

# %%
resp.groupby('exercise').income_weekly.mean()
# Out:
# exercise
# 0.0     473.075000
# 1.0     762.393819
# 2.0    1028.856604
# Name: income_weekly, dtype: float64

# %%
resp.boxplot(column='income_weekly', by='exercise')
plt.savefig('exercise_box.png', transparent=True)

# %%
resp.boxplot(column='bmi', by='income_lvl')
plt.savefig('bmi_box.png', transparent=True)

# %%
resp.boxplot(column='primary_eating', by='income_lvl')
plt.ylim((0,200))
plt.savefig('prim_box.png', transparent=True)

# %%
resp.boxplot(column='secondary_eating', by='income_lvl')
plt.ylim((0,150))
# Out:
# (0, 150)

# %%
resp.income_lvl.mean()
# Out:
# 0.7556521739130435

# %%
resp.income_weekly.mean()
# Out:
# 940.5365750736452
